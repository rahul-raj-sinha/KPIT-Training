# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use("fivethirtyeight")

# %%
DF = pd.DataFrame(np.random.randn(10, 4), columns=list("ABCD"))
print(DF.head())
# Out:
#           A         B         C         D
# 0  1.901719 -0.133906  0.917956  0.237719
# 1 -1.559478  0.009560 -0.735602  0.042185
# 2  0.310020 -1.707032 -0.248373  2.007567
# 3  0.030466  1.144921  1.653808 -0.527414
# 4 -1.794729  1.523418 -0.112292 -0.587138

# %%
DF.plot.area(stacked=False)
# Out:
# <Axes: >

# %%
iris = pd.read_csv("C:\\Users\\Kiran\\CDAC\\Day16\\iris.data", header=None)
iris.columns = ["sepal_length", "sepal_width", "petal_length", 
                "petal_width", 'species']

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
print(iris.plot.area())
# Out:
# Axes(0.08,0.07;0.87x0.81)

# %%
iris.plot.area(stacked=False)
# Out:
# <Axes: >

# %%
DF.plot.scatter(x="A", y="B")
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
movies = pd.read_csv("C:\\Users\\Kiran\\CDAC\\Day16\\imdbratings.txt")
print(movies.head())
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
print(movies.dtypes)
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.plot.scatter(x="star_rating", y="duration")
# Out:
# <Axes: xlabel='star_rating', ylabel='duration'>
