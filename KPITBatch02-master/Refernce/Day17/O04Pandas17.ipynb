# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.style.use("fivethirtyeight")

# %%
data = pd.Series(np.random.randn(1000).cumsum())
print(data)
# Out:
# 0      -2.299287
# 1      -2.021322
# 2      -2.190476
# 3      -1.515760
# 4      -1.937257
#          ...
# 995   -18.879370
# 996   -17.699360
# 997   -16.644811
# 998   -18.050839
# 999   -16.529879
# Length: 1000, dtype: float64

# %%
data.plot()
# Out:
# <Axes: >

# %%
DF = pd.DataFrame(np.random.randn(1000, 4), columns=list("ABCD"))
print(DF)
# Out:
#             A         B         C         D
# 0    0.125086 -0.414293  1.262847 -1.741214
# 1    1.316269  1.662858 -1.175195  0.284296
# 2    1.072101  1.426912 -0.255879 -0.004353
# 3   -0.909913  0.648503  0.972904  1.027238
# 4   -0.265294 -1.299236 -1.119620 -0.086896
# ..        ...       ...       ...       ...
# 995 -0.225485  0.745247 -0.354432  1.085712
# 996 -0.493819 -0.165328 -1.581888  0.407346
# 997 -0.295567 -1.027145  1.450994 -0.138623
# 998 -0.587542  0.460499  0.219749  1.113019
# 999 -0.392070  0.728215 -1.742563 -0.245042
#
# [1000 rows x 4 columns]

# %% [markdown]
# DF1 = DF.cumsum()
# print(DF1)

# %%
DF1 = DF.cumsum()
print(DF1)
# Out:
#              A          B          C          D
# 0     0.125086  -0.414293   1.262847  -1.741214
# 1     1.441355   1.248565   0.087652  -1.456918
# 2     2.513456   2.675477  -0.168227  -1.461271
# 3     1.603544   3.323980   0.804677  -0.434033
# 4     1.338249   2.024744  -0.314943  -0.520929
# ..         ...        ...        ...        ...
# 995  83.822418  30.812723 -48.504611  43.843870
# 996  83.328598  30.647395 -50.086499  44.251216
# 997  83.033032  29.620250 -48.635505  44.112593
# 998  82.445490  30.080749 -48.415755  45.225612
# 999  82.053419  30.808964 -50.158318  44.980570
#
# [1000 rows x 4 columns]

# %%
DF1.plot()
# Out:
# <Axes: >

# %%
# Bar chart
DF.iloc[10]
# Out:
# A    0.795970
# B    1.147863
# C    1.039592
# D    1.171538
# Name: 10, dtype: float64

# %%
DF.iloc[10].plot(kind="bar")
# Out:
# <Axes: >

# %%
DF2 = pd.DataFrame(np.random.rand(7, 3), columns=list("ABC"))
print(DF2)
# Out:
#           A         B         C
# 0  0.768307  0.338190  0.944385
# 1  0.613713  0.028357  0.922617
# 2  0.743173  0.502372  0.001468
# 3  0.536043  0.597600  0.859198
# 4  0.331386  0.844048  0.401807
# 5  0.677376  0.041462  0.768418
# 6  0.456683  0.710059  0.201919

# %%
DF2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
DF2.plot.bar()
# Out:
# <Axes: >

# %%
DF2.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
DF2.plot.barh()
# Out:
# <Axes: >

# %%
iris = pd.read_csv("C:\\Users\\Kiran\\CDAC\\Day16\\iris.data", header=None)
iris.columns = ["sepal_length", "sepal_width", "petal_length", 
                "petal_width", 'species']

# %%
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.plot.hist(alpha=0.7)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=1, stacked=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=1, stacked=True, bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris['sepal_width'].plot.hist(orientation="horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris.hist(color="blue", alpha=1, bins=20)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
iris.plot.box(vert=False)
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"]=(8, 8)
plt.style.use("ggplot")
iris.boxplot(by="species")
# Out:
# array([[<Axes: title={'center': 'petal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'petal_width'}, xlabel='[species]'>],
#        [<Axes: title={'center': 'sepal_length'}, xlabel='[species]'>,
#         <Axes: title={'center': 'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)
