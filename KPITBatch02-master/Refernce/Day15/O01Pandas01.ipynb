# %%
import pandas as pd

mydataset = {
    'cars' :['Tata',  'Mahindra', "Maruti"],
    'safety' : [5, 3, 2]
 }

print(mydataset)

pdDF = pd.DataFrame(mydataset)

print(pdDF)

print("-" * 60)

print("Pandas Version -", pd.__version__)
# Out:
# {'cars': ['Tata', 'Mahindra', 'Maruti'], 'safety': [5, 3, 2]}
#        cars  safety
# 0      Tata       5
# 1  Mahindra       3
# 2    Maruti       2
# ------------------------------------------------------------
# Pandas Version - 1.5.3

# %%
conda update pandas
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following NEW packages will be INSTALLED:
#
#   anaconda-anon-usa~ pkgs/main/win-64::anaconda-anon-usage-0.4.3-py311hfc23b7f_100
#   anaconda-cloud-au~ pkgs/main/win-64::anaconda-cloud-auth-0.1.4-py311haa95532_0
#   aom                pkgs/main/win-64::aom-3.6.0-hd77b12b_0
#   archspec           pkgs/main/noarch::archspec-0.2.1-pyhd3eb1b0_0
#   async-lru          pkgs/main/win-64::async-lru-2.0.4-py311haa95532_0
#   brotli-python      pkgs/main/win-64::brotli-python-1.0.9-py311hd77b12b_7
#   datasets           pkgs/main/win-64::datasets-2.12.0-py311haa95532_0
#   dav1d              pkgs/main/win-64::dav1d-1.2.1-h2bbff1b_0
#   grpc-cpp           pkgs/main/win-64::grpc-cpp-1.48.2-hfe90ff0_1
#   huggingface_hub    pkgs/main/win-64::huggingface_hub-0.17.3-py311haa95532_0
# ...

# %%
cars = ['tata', 'maruti suzuki', 'honda', 'hyundai' ]

print(cars)

print(pd.__version__)
# Out:
# ['tata', 'maruti suzuki', 'honda', 'hyundai']
# 1.5.3
